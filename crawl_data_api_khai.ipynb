# %%
import requests
import json

# %% [markdown]
# - Get all shops

# %%
all_shops_API = requests.get("https://www.foody.vn/__get/Place/HomeListPlace?page=1&count=100&districtId=&cateId=&cuisineId=&type=1", 
                            headers={'X-Requested-With': 'XMLHttpRequest'})
data = all_shops_API.text
dataJson = json.loads(data)
print(dataJson)
# Out:
# {'CityId': 218, 'ExcludeIds': None, 'Query': None, 'Items': [{'Id': 100814, 'Name': 'Chân Gà Nướng Thịnh Vượng', 'Address': '5 Lý Văn Phức, P. Cát Linh, Quận Đống Đa, Hà Nội', 'AvgRating': 9.238, 'AvgRatingText': '9.2', 'RestaurantStatus': 2, 'Phone': 'Đang cập nhật', 'PhotoUrl': 'https://images.foody.vn/res/g11/100814/prof/s640x400/image-c1a2907a-200822063502.jpeg', 'TotalReviews': 26, 'TotalFavourites': 0, 'TotalViews': 0, 'TotalPictures': 36, 'TotalCheckIns': 0, 'Url': '/ha-noi/chan-ga-nuong-thinh-vuong', 'Tags': None, 'Description': None, 'Note': {'RestaurantId': 0, 'UserId': 0, 'ListId': None, 'ListName': None, 'CreatedOn': '/Date(-62135596800000)/', 'Description': None, 'Id': 0}, 'HasPromotion': False, 'HasMemberCard': False, 'MemberCardDiscount': None, 'Latitude': 21.030894, 'Longitude': 105.831942, 'ResUsername': None, 'ResCreatedOn': '/Date(-62135596800000)/', 'LstPicture': [], 'LstReview': [{'reviewProfileUrl': '/thanh-vien/anhquynhle1999', 'reviewUserDisplayName': 'Qa Le', 'reviewUserAvatar': 'https://images.foody.vn/usr/g180/1796108/avt/c100x100/anhquynhle1999-avatar-203-637133301466614059.jpg', 'reviewUrl': '/ha-noi/chan-ga-nuong-thinh-vuong/binh-luan-10072503', 'AvgRatingText': '10.0', 'ShortReview': False, 'UserVerified': False, 'ReviewId': 10072503, 'Comment': 'Mình đã gọi 2 tuần liên tiếp rồii không thể không review 😭😭 trời ơi sườn nướng ngon tuyệt cú mèo luônn cả bánh mì bơ, sốt ớt, dưa chuột, rau muống đều cho nhiều dã man', 'UserId': 1796108, 'UserFoodyId': 0, 'Username': 'Le', 'UserAvatar': 'anhquynhle1999-avatar-203-637133301466614059.jpg', 'UserGender': 'female', 'UserFirstName': 'Qa', 'UserLastName': 'Le', 'AvgRating': 10.0}, {'reviewProfileUrl': '/thanh-vien/dolananhmailphu', 'reviewUserDisplayName': 'Đỗ Lan Anh', 'reviewUserAvatar': 'https://images.foody.vn/usr/g877/8765855/avt/c100x100/beauty-upload-api-foody-avatar-716f2be2-abd4-4f84-9f67-ea7a6b3be183-191112112837.jpg', 'reviewUrl': '/ha-noi/chan-ga-nuong-thinh-vuong/binh-luan-7007728', 'AvgRatingText': '8.6', 'ShortReview': False, 'UserVerified': False, 'ReviewId': 7007728, 'Comment': 'Mình thích ăn chân chiên hơn là chân nướng, vì mấy lần mua ở chỗ khác fail quá, mùi thì cũng thơm nhưng ăn chẳng có vị gì, nước chấm lại vừa cạy vừa ngọt :(. Nhưng ăn ở đây thì khác, tẩm ướp rất vừa miệng, ...', 'UserId': 8765855, 'UserFoodyId': 0, 'Username': 'Lan Anh', 'UserAvatar': 'beauty-upload-api-foody-avatar-716f2be2-abd4-4f84-9f67-ea7a6b3be183-191112112837.jpg', 'UserGender': 'F', 'UserFirstName': 'Đỗ', 'UserLastName': 'Lan Anh', 'AvgRating': 8.6}], 'LstCategory': None, 'LstCuisine': None, 'PriceMin': None, 'PriceMax': None, 'PriceMinDisplay': None, 'PriceMaxDisplay': None, 'DisplayOrder': None, 'City': None, 'District': None, 'FAvgRating': 6, 'FTotalReviews': 7, 'ResUrlAlbums': '/ha-noi/chan-ga-nuong-thinh-vuong/album-anh', 'ResUrlReviews': '/ha-noi/chan-ga-nuong-thinh-vuong/binh-luan', 'ContributeStatus': None, 'CanDelete': False, 'ListOwnerId': 0, 'ListId': 0, 'UserId': 0, 'IsRestaurantCollection': False, 'Services': [{'Id': 1, 'Type': 0, 'Url': 'https://www.deliverynow.vn/ha-noi/chan-ga-nuong-thinh-vuong', 'Title': 'ShopeeFood', 'Text': 'Giao tận nơi', 'Avatar': '/style/images/40x40_icon-deliverynow.png', 'BackgroundColor': '#CE332F', 'RestaurantId': 100814, 'Description': None}], 'TotalService': 1, 'UrlRewriteName': 'chan-ga-nuong-thinh-vuong', 'LocationUrlRewriteName': 'ha-noi', 'RestaurantId': 100814, 'MainCategoryId': 0, 'TotalSaves': 219, 'Status': 0, 'TotalSavesFormat': '219', 'TotalReviewsFormat': '26', 'TotalPicturesFormat': '36', 'IsAds': True, 'MobileBgColor': '#000000', 'IsBooking': False, 'IsDelivery': True, 'BookingUrl': '', 'DeliveryUrl': '/ha-noi/chan-ga-nuong-thinh-vuong/goi-mon', 'HasVideo': False, 'HasBooking': False, 'HasDelivery': False, 'MasterCategoryId': 1, 'PromotionId': None, 'PromotionTitle': None, 'PromotionUrl': None, 'Floor': None, 'IsSaved': False, 'IsOpening': True, 'Distance': 0, 'PromotionPlainTitle': None, 'DistanceText' ...

# %% [markdown]
# - Get menu of ONE shop: fải loop qua từng request_id trong cell code trên

# %%
# VD: có thể thay request_id = 1031704 để thử
delivery_dish_API = requests.get(f"https://gappapi.deliverynow.vn/api/dish/get_delivery_dishes?request_id={request_id}&id_type=1", 
                                    headers={'x-foody-api-version': '1',
                                            'x-foody-app-type': '1004',
                                            'x-foody-client-language': 'vi',
                                            'x-foody-client-type': '1',
                                            'x-foody-client-version': '1',
                                            'X-Foody-Client-Id': 'cookies.__ondemand_sessionid'
                                        }
                                )
data = delivery_dish_API.text
dataJson = json.loads(data)
print(dataJson)

# %% [markdown]
# - get detail of ONE shop

# %%
delivery_dish_API = requests.get("https://gappapi.deliverynow.vn/api/delivery/get_detail?request_id={request_id}&id_type=1", 
                                    headers={'x-foody-api-version': '1',
                                            'x-foody-app-type': '1004',
                                            'x-foody-client-language': 'vi',
                                            'x-foody-client-type': '1',
                                            'x-foody-client-version': '1',
                                            'X-Foody-Client-Id': 'cookies.__ondemand_sessionid'
                                        }
                                )
data = delivery_dish_API.text
dataJson = json.loads(data)
print(dataJson)
# Out:
# {'reply': {'delivery_detail': {'total_order': 0, 'rating': {'total_review': 500, 'avg': 4.7, 'display_total_review': '500+', 'app_link': 'foody://foody.vn?action=reviewlist&id=1031704'}, 'is_subscribe': False, 'is_favorite': False, 'city_id': 217, 'phones': ['0776969606'], 'restaurant_id': 1031704, 'district_id': 16, 'brand_id': 11607, 'video': None, 'asap_is_available': False, 'contract_type': 1, 'id': 121227, 'location_url': 'ho-chi-minh', 'foody_service_id': 1, 'is_quality_merchant': True, 'available_times': [{'date': '2022-09-21', 'times': ['09:55', '10:00', '10:05', '10:10', '10:15', '10:20', '10:25', '10:30', '10:35', '10:40', '10:45', '10:50', '10:55', '11:00', '11:05', '11:10', '11:15', '11:20', '11:25', '11:30', '11:35', '11:40', '11:45', '11:50', '11:55', '12:00', '12:05', '12:10', '12:15', '12:20', '12:25', '12:30', '12