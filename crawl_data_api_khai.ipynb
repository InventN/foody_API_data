# %%
import requests
import json

# %%
response_API = requests.get("https://www.foody.vn/__get/Place/HomeListPlace?page=1&count=10&districtId=&cateId=&cuisineId=&type=1", headers={"X-Requested-With": "XMLHttpRequest"})
print(response_API.status_code)


data = response_API.text
dataJson = json.loads(data)
# 

print(dataJson)
# Out:
# 200
# ...
